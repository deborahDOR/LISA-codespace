# %% [markdown]
# # Galactic binary and superradiance data analysis

# %% [markdown]
# ## 0 Imports

# %%
import ldc.waveform.fastGB as FB
from ldc.lisa import orbits
from astropy import units as un
import numpy as np
#from memory_profiler import profile
import fastGB as FB_MLDC
import matplotlib.pyplot as plt
import math
from scipy.special import gamma,gammainc,gammaincc
import scipy.integrate as integr
import spritz

from spritz import utils, inference, masking, waveforms, sampling
from ldc.lisa import orbits
from ldc.lisa.noise import get_noise_model

import matplotlib.pyplot as plt
from ldc.lisa.orbits import Orbits
from ldc.waveform.waveform import HpHc
from ldc.lisa.projection import ProjectedStrain
import ldc.io.yml as ymlio
import os
import h5py
import ldc.waveform.fastGB as FB
from ldc.common.series import TimeSeries
from ldc.common import constants
plt.rcParams['text.usetex']=True

# %% [markdown]
# ## 1 Generate GW signal

# %%
#SourceParameters(New lambda and beta values)
lamb_test=85*(np.pi/180)
beta_test=15*(np.pi/180)
i=np.arccos(0.70144304)
tab_Param=(1.43327232e-22,  beta_test, lamb_test,0.00774, 2.3961e-21, 0.79337616, 0.41646956,4.91653383)

# %%
print(beta_test)
print(lamb_test)
print(i)
# Out:
# 0.2617993877991494
# 1.4835298641951802
# 0.7933761635537875

# %%
Tobs = 365*24*60*60*0.5
dt = 15.0

config = {"dt":dt, "initial_position": 0, "initial_rotation": 0, 
          "nominal_arm_length": 2500000000, "orbit_type": 'analytic', 
          "t_max": Tobs, "t_min": 0, "travel_time_order": 1}


cat = np.array([tab_Param],
               dtype=[('Amplitude', '<f8'),
                      ('EclipticLatitude', '<f8'),
                      ('EclipticLongitude', '<f8'),
                      ('Frequency', '<f8'), ('FrequencyDerivative', '<f8'),
                      ('Inclination', '<f8'), ('InitialPhase', '<f8'),
                      ('Polarization', '<f8')])

# %%
# Set orbit model
lisa_orbits = orbits.Orbits.type(dict({"nominal_arm_length":2.5e6*un.km,
                                    "initial_rotation":0*un.rad,
                                    "initial_position":0*un.rad,
                                    "orbit_type":"analytic"}))

# %%
GB = FB.FastGB(delta_t=dt, T=Tobs, orbits=lisa_orbits)
pGB = dict(zip(cat.dtype.names, cat[0]))

# %%
X2_t,Y2_t,Z2_t=GB.get_td_tdixyz(template=pGB,oversample=4,tdi2=True)
N = len(X2_t)

# %%
plt.plot(X2_t.t, X2_t, alpha=0.5, label="fastGB",linestyle='dashed')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
def XYZ2AET(X, Y, Z):
    A,E,T = ((Z - X)/np.sqrt(2.0),
            (X - 2.0*Y + Z)/np.sqrt(6.0),
            (X + Y + Z)/np.sqrt(3.0))
    if hasattr(X, "attrs"):
        A.attrs = X.attrs
    return A,E,T

# %%
# Get AET from XYZ (devide by dt to have the units of strain only)
A_t, E_t, T_t = XYZ2AET(X2_t, Y2_t, Z2_t)
aet_signal = np.asarray([channel.to_numpy() for channel in [A_t, E_t, T_t]]).T

# %%
plt.plot(X2_t.t, aet_signal[:, 0], alpha=0.5, label="fastGB",linestyle='dashed')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %% [markdown]
# ## 2 Generate noise

# %%
import backgroundsmaster
from backgroundsmaster.backgrounds.utils import generate_noise
#from backgrounds.utils import generate_noise

# %%
f_tot=np.fft.fftfreq(N)/dt
noise_model = get_noise_model('SciRDv1', f_tot[f_tot>0], wd=False)

# %%
# noise PSDs
def psd_a(freq):
    return noise_model.psd(freq=freq, option='A', tdi2=True)
def psd_t(freq):
    return noise_model.psd(freq=freq, option='T', tdi2=True)

f_sampling = 1/dt
a_noise = generate_noise(psd_func=psd_a, n_data=N, fs=f_sampling)
e_noise = generate_noise(psd_func=psd_a, n_data=N, fs=f_sampling)
t_noise = generate_noise(psd_func=psd_t, n_data=N, fs=f_sampling)
aet_noise = np.asarray([a_noise, e_noise, t_noise]).T

# %%
t = np.linspace(0,Tobs,N)
plt.plot(t, aet_noise[:, 0])
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# ## 3. Compare noise and signal in the frequency domain

# %%
aet_noise_f = np.fft.fft(aet_noise, axis=0)*dt
aet_signal_f = np.fft.fft(aet_signal, axis=0)*dt

# %%
# Fourier transform
plt.figure(0)
plt.loglog(f_tot[f_tot>0], np.abs(aet_noise_f[f_tot>0, 0]), 
           label="Noise FFT")
plt.loglog(f_tot[f_tot>0], np.abs(aet_signal_f[f_tot>0, 0]), 
           label="Signal FFT")
# plt.xlim([0.00715, 0.00765])
plt.legend(loc="upper left")
plt.xlim([tab_Param[3]*(1-0.001), tab_Param[3]*(1+0.001)])
plt.ylim([1e-19, 1e-15])
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
X2_f, Y2_f, Z2_f = GB.get_fd_tdixyz(template=pGB, tdi2=True)
A_f, E_f, Z_f = XYZ2AET(X2_f, Y2_f, Z2_f)

# %%
#Definition of the frequency window 
f0 = tab_Param[3]
p1 = np.argmin(np.abs(X2_f.f.to_numpy()[0]-f_tot))
#p1 = np.argmin(np.abs(X2_f.f.to_numpy()[10]-f_tot))
p2 = np.argmin(np.abs(X2_f.f.to_numpy()[-1]-f_tot))

# %%
ids=np.arange(p1, p2+1)
print(len(ids))
print(len(X2_f.f))
# Out:
# 64
# 64

# %%
# d_t = aet_signal + aet_noise
aet_data_f = aet_signal_f + aet_noise_f
d = aet_data_f[ids]

# %% [markdown]
# ## 4. Compare waveforms from data and generator

# %%
plt.figure(figsize=(12,6))
plt.subplot(111)
plt.plot(f_tot[ids]*1e3,
         np.abs(aet_signal_f[ids, 0]),
         label="TDI A (noiseless)",
         color="blue")
plt.plot(f_tot[ids]* 1e3, np.abs(d[:, 0]),
         label="TDI A (noisy)",
         color='black')
plt.plot(X2_f.f*1e3, np.abs(A_f),
         label="Fast waveform",
         color="orange",
         linestyle='dashed')
plt.legend(loc="upper right")
plt.xlabel("Frequency [mHz]")
plt.ylabel("TDI X Amplitude [s]")
# plt.xlim([7.715,7.765])
# plt.ylim([-0.05e-16,2.5e-16])
plt.show()

# %%
# Set waveform model
my_gb = waveforms.MyFastGB(delta_t=dt, T=Tobs, orbits=lisa_orbits) # in seconds

# %%
# Set noise model
wd = False
noise_model = get_noise_model('SciRDv1', f_tot[f_tot>0], wd=wd)

# %%
# Set likelihood
wd = np.ones(N)
a_data = aet_data_f[:, 0]
e_data = aet_data_f[:, 1]
loglike_cls = inference.GBLikelihood(f_tot, [a_data, e_data], 
                                     noise_model=noise_model, 
                                     signal_model=my_gb,
                                     wd=wd)

# %%
X2_f, Y2_f, Z2_f = my_gb.get_fd_tdixyz(template=pGB, tdi2=True)
A_f, E_f, Z_f = XYZ2AET(X2_f, Y2_f, Z2_f)

# %%
# There is some ambiguity in the choice of beta and lambda
p_sample_true_0 = utils.waveform2sample(pGB)
# p_sample_true = np.copy(p_sample_true_0)
# p_sample_true[4] = p_sample_true[4] + np.pi
p_sample_true = p_sample_true_0[:]

# %%
fr, kmin, signal_ae = loglike_cls.compute_waveform(p_sample_true)

# %%
print(type(signal_ae[0]))
print(type(fr))
signal_a = signal_ae[0].to_numpy()
fr_a = fr.to_numpy()
# Out:
# <class 'xarray.core.dataarray.DataArray'>
# <class 'xarray.core.dataarray.DataArray'>

# %%
plt.figure(figsize=(12,6))
plt.subplot(111)
plt.plot(f_tot[ids]*1e3,
         np.abs(aet_data_f[ids, 0]),
         label="Data",
         color="blue")
plt.plot(A_f.f * 1e3, np.abs(A_f),
         label="FastGB waveform",
         color='red')
plt.plot(fr_a * 1e3, np.abs(signal_a),
         label="Likelihood waveform",
         color='black')
plt.legend(loc="upper right")
plt.xlabel("Frequency [mHz]")
plt.ylabel("TDI A Amplitude [s]")
# plt.xlim([7.715,7.765])
# plt.ylim([-0.05e-16,2.5e-16])
plt.show()

# %%
# Lower bounds
a = np.array([p_sample_true[0] - 1, p_sample_true[1] - 1e-3, -21.5, -1.0, -np.pi, -1.0, 0.0, 0.0])
# Upper bounds
b = np.array([p_sample_true[0] + 1, p_sample_true[1] + 1e-3, -19.5, 1.0, np.pi, 1.0, 2.0*np.pi, 2.0*np.pi])

# %%
def shift_param(theta_ref, ip, dp):
    theta_shifted = np.copy(theta_ref)
    theta_shifted[ip] += dp
    return theta_shifted

# %%
print(p_sample_true)
# Out:
# [-21.84367129   7.74       -20.62049506   0.25881905   1.48352986
#    0.70144304   4.91653383   0.41646956]

# %%
param_names = [r"$\log_{10}(A)$", 
               r"$f_0$", 
               r"$\log_{10}(\dot{f}_0)$", 
               r"$\sin \beta$", 
               r"$\lambda$", 
               r"$\cos\i$", 
               r"$\Psi$", 
               r"$\phi_0$"]
j_param = 0
var_max = 1
dlog_amp = np.arange(-var_max, var_max, 0.05)
p_values = [shift_param(p_sample_true, j_param, dl) for dl in dlog_amp]
ll_values = np.array([loglike_cls.evaluate(p) for p in p_values])
i_max = np.argmax(ll_values)

# %%
fix, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
ax.plot(dlog_amp, ll_values, marker='+')
# ax.legend(loc='upper left')
ax.vlines(dlog_amp[i_max], np.min(ll_values), 
          ll_values[i_max], color='red', linestyle='dashed')
# ax.set_xlabel(r"$\log (\Omega / 10^{-14})$")
ax.set_xlabel(r"Error on " + param_names[j_param])
ax.set_ylabel("Log-likelihood")
ax.grid(linestyle='dotted')
plt.show()

# %%
j_param = 1
dlog_f = np.linspace(a[j_param], b[j_param], 1000) - p_sample_true[j_param]
p_values = [shift_param(p_sample_true, j_param, dl) for dl in dlog_f]
ll_values = np.array([loglike_cls.evaluate(p) for p in p_values])
i_max = np.argmax(ll_values)

# %%
fix, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
ax.plot(dlog_f, ll_values, marker='+')
# ax.legend(loc='upper left')
ax.vlines(dlog_f[i_max], np.min(ll_values), 
          ll_values[i_max], color='red', linestyle='dashed')
# ax.set_xlabel(r"$\log (\Omega / 10^{-14})$")
ax.set_xlabel(r"Error on " + param_names[j_param])
ax.set_ylabel("Log-likelihood")
ax.grid(linestyle='dotted')
plt.show()

# %%
j_param = 3
dlog_f = np.linspace(a[j_param], b[j_param], 100) - p_sample_true[j_param]
p_values = [shift_param(p_sample_true, j_param, dl) for dl in dlog_f]
ll_values = np.array([loglike_cls.evaluate(p) for p in p_values])
i_max = np.argmax(ll_values)


fix, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
ax.plot(dlog_f, ll_values, marker='+')
# ax.legend(loc='upper left')
ax.vlines(dlog_f[i_max], np.min(ll_values), 
          ll_values[i_max], color='red', linestyle='dashed')
# ax.set_xlabel(r"$\log (\Omega / 10^{-14})$")
ax.set_xlabel(r"Error on " + param_names[j_param])
ax.set_ylabel("Log-likelihood")
ax.grid(linestyle='dotted')
plt.show()

# %%
j_param = 4
dlog_f = np.linspace(a[j_param], b[j_param], 100) - p_sample_true[j_param]
p_values = [shift_param(p_sample_true, j_param, dl) for dl in dlog_f]
ll_values = np.array([loglike_cls.evaluate(p) for p in p_values])
i_max = np.argmax(ll_values)


fix, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
ax.plot(dlog_f, ll_values, marker='+')
# ax.legend(loc='upper left')
ax.vlines(dlog_f[i_max], np.min(ll_values), 
          ll_values[i_max], color='red', linestyle='dashed')
# ax.set_xlabel(r"$\log (\Omega / 10^{-14})$")
ax.set_xlabel(r"Error on " + param_names[j_param])
ax.set_ylabel("Log-likelihood")
ax.grid(linestyle='dotted')
plt.show()

# %%
def loglike(p):
    #if (np.all(a <=p) and np.all(b >=p)):
    loglike_cls = inference.GBLikelihood(f_tot[ids], [a_data, e_data], 
                                     noise_model=noise_model, 
                                     signal_model=my_gb,
                                     wd=wd)
    #fr, kmin, signal_ae = loglike_cls.compute_waveform(p)
    return loglike_cls.evaluate(p)
print(loglike(a))
print(loglike(p_sample_true))
print(loglike(b))
# Out:
# -119.6094188737148
# 3699.947252622091
# -765814.6300635226

# %%
#priors
c = 299792458.03
f_star=19.3e-3
phi_star=10

#Amplitude
def Sn_pos(f):
    return 4.84e-42

def Sn_acc(f):
    return 2.31e-40*(1e-3/f)**4


def S_A(f):
    return 4*Sn_pos(f)+8*(1+np.cos(f/f_star)**2)*(Sn_acc(f)/(2*np.pi*f)**4)

def rho(Tobs,f,A):
    return A/2*np.sqrt((Tobs*np.sin(f/f_star)/S_A(f)/f))

def P_snr(rho):
    return (3*rho)/((4*phi_star**2)*(1+(rho/(4*phi_star)))**5)

f0=tab_Param[3]

def logP_A(x):
    x=10**x
    D=2*np.sqrt((S_A(f0)/(Tobs*np.sin(f0/f_star)**2)))
    return -np.log(D)+np.log(P_snr(x/D))

def logP_A_bis(x):
    x=float(10**x)
    D=2*np.sqrt((S_A(f0)/(Tobs*np.sin(f0/f_star)**2)))
    return float(np.log(3)-2*np.log(D)-4*np.log(4*phi_star**2)+np.log(x)-5*np.log(1+(x/(4*D*phi_star))))
    

#Position
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.coordinates import BarycentricMeanEcliptic, Galactic, Galactocentric

def sech2(x):
    return 1/np.cosh(x)

def log_pos(lon, lat):
    lon=lon+np.pi
    lat=np.arcsin(lat)
    sky_ecl = SkyCoord(lon=lon*u.rad,
                       lat=lat*u.rad, distance=8*u.kpc, frame='barycentricmeanecliptic')
    #sky_gal = sky_ecl.transform_to(Galactic).cartesian
    sky_gal = sky_ecl.transform_to(Galactocentric).cartesian
    alpha = 0.25; Rb = 0.8; Rd = 2.5; Zd = 0.4
    r2 = sky_gal.x**2+sky_gal.y**2+sky_gal.z**2
    u2 = sky_gal.x**2+sky_gal.y**2
    e1 = -r2/Rb**2
    e2 = -np.sqrt(u2)/Rd
    s = sky_gal.z.value/Zd
    p = alpha*np.exp(e1.value)+(1-alpha)*np.exp(e2.value)*sech2(s)
    return float(np.log(alpha*np.exp(e1.value))+np.log(1+(((1-alpha)*np.exp(e2.value)*sech2(s))/(alpha*np.exp(e1.value)))))

# %%
print(log_pos(p_sample_true[4],p_sample_true[3]))
print(log_pos(a[4],a[3]))
print(log_pos(b[4],b[3]))
# Out:
# -4.596592995059755
# -13.525478448541406
# -14.093383296394393

# %%
#Computation of the loglikelihood

def logprior_set(theta,a,b):
    if (np.all(a <=theta) and np.all(b >= theta)):
        logA,f,logfdot,sinbeta,lamb,cos_i,pol,ph=theta
        p=logP_A_bis(logA)+log_pos(lamb,sinbeta)
    
    else :
        p=-np.inf
       
    return p

# %%
print(logprior_set(a,a,b))
print(logprior_set(p_sample_true,a,b))
print(logprior_set(b,a,b))
# Out:
# 8.974713531221585
# 20.175994462677828
# 12.689514074934632

# %%
import corner
import ptemcee
from PTMCMCSampler import PTMCMCSampler
import time

class HDF5Store(object):
    """
    Simple class to append value to a hdf5 file on disc (usefull for building keras datasets)
    
    Params:
        datapath: filepath of h5 file
        dataset: dataset name within the file
        shape: dataset shape (not counting main/batch axis)
        dtype: numpy dtype
    
    Usage:
        hdf5_store = HDF5Store('/tmp/hdf5_store.h5','X', shape=(20,20,3))
        x = np.random.random(hdf5_store.shape)
        hdf5_store.append(x)
        hdf5_store.append(x)
        
    From https://gist.github.com/wassname/a0a75f133831eed1113d052c67cf8633
    """
    def __init__(self, datapath, dataset, shape, dtype=np.float32, 
                 compression="gzip", chunk_len=1):
        self.datapath = datapath
        self.dataset = dataset
        self.shape = shape
        self.i = 0

        # Create the file if it does not already exists
        if not os.path.isfile(self.datapath):
            with h5py.File(self.datapath, mode='w') as h5f:
                self.dset = h5f.create_dataset(
                    dataset,
                    shape=(0, ) + shape,
                    maxshape=(None, ) + shape,
                    dtype=dtype,
                    compression=compression,
                    chunks=(chunk_len, ) + shape)
    
    def append(self, values):
        """
        Append more value to dataset.
        
        Parameters
        ----------
        values : ndarray
            Array of values to append. Should have shape (n_values, shape)
        
        """
        with h5py.File(self.datapath, mode='a') as h5f:
            dset = h5f[self.dataset]
            values_shape = np.shape(values)
            
            # Check that the number of dimensions is the same
            if len(values_shape) == len(self.shape):
                n_values = 1
            # If it's not, there is more than one value to add
            elif len(values_shape) > len(self.shape):
                n_values = values_shape[0]
            else:
                raise ValueError("There is a dimension problem.")
            dset.resize((self.i + n_values, ) + self.shape)
            dset[-n_values:] = [values]
            self.i += n_values
                
            h5f.flush()

    def load(self):
        with h5py.File(self.datapath, mode='r') as h5f:
            dset = h5f[self.dataset][()]
        return dset    

    @staticmethod
    def chain_to_save(chain):
        ntemps, nwalkers, nsteps, ndim = np.shape(chain)
        reshaped_chain = np.zeros((nsteps, ntemps, nwalkers, ndim))
        for i in range(nsteps):
            reshaped_chain[i, :, :, :] = chain[:, :, i, :]
        
        return reshaped_chain
    
    @staticmethod
    def save_to_chain(reshaped_chain):

        nsteps, ntemps, nwalkers, ndim = np.shape(reshaped_chain)
        chain = np.zeros((ntemps, nwalkers, nsteps, ndim))
        for i in range(nsteps):
            chain[:, :, i, :] = reshaped_chain[i, :, :, :]
        
        return chain

# %%
#not useful if multiprocessing is chosen
ndim = len(p_sample_true)
nwalkers = 8 * ndim
ntemps = 20
nit = 7000
thin = 1

# Instantiate the sampler
sampler = ptemcee.Sampler(nwalkers, ndim, loglike,
                              logprior_set, ntemps=int(ntemps),
                              loglargs=[],
                              logpargs=[a,b],
                              pool=None)

# %%
from multiprocessing import Pool
import os
import time
#Needs to disable numpy internal multithreading 
# # as it does not get along well with multiprocessing
os.environ["OMP_NUM_THREADS"] = "1"
# # pool = None
ndim = len(p_sample_true)
nwalkers = 8 * ndim
ntemps = 20

# Intialize the parameter state
pos = np.random.uniform(low=a,high=b,size=(ntemps, nwalkers, ndim))

# Number of iterations
n_iter = 80000
n_thin = 1
# Save results every 100 samples
n_save = 100
# Print progress every 200 samples
n_verbose = 200
# Initialize iteration counter
i = 0
isave = 0

output_dir = "./"
chain_suffix = "mychains3008ucbLongNewtest.h5"
# logl_suffix = "mylogl.h5"
# logp_suffix = "mylogp.h5"

hdf5 = HDF5Store(output_dir + chain_suffix, 
                 "chains", 
                 np.shape(pos), 
                 dtype=float, 
                 compression="gzip", 
                 chunk_len=1)

# Block of chain to be saved
nsize = np.min([n_save, n_iter])
chain_save = np.zeros((ntemps, nwalkers, nsize, ndim))
logl_save = np.zeros((ntemps, nwalkers, nsize))
logp_save = np.zeros((ntemps, nwalkers, nsize))
t1 = time.time()


with Pool(8) as pool:
    sampler = ptemcee.Sampler(nwalkers, ndim, loglike, logprior_set, 
                              logpargs=[a,b], 
                              ntemps=ntemps,
                              pool=pool)
    for pstate, lnlike0, lnprob0 in sampler.sample(pos, n_iter, thin=n_thin, storechain=True):
    
        # Store data
        chain_save[:, :, isave, :] = pstate
        logl_save[:, :, isave] = lnlike0
        logp_save[:, :, isave] = lnprob0

        if isave == n_save - 1:
            # If the number of iterations in a multiple of n_save
            print("Save data at iteration " + str(i) + "...")
            # The number of saved iterations at iteration i is
            # saved_it = i // thin
            # ------Samples---------

            hdf5.append(hdf5.chain_to_save(chain_save))
            # ------Log likelihood---------
            # ------Log prior---------
            print("Data saved.")
            # Update the number of samples saved
            isave += nsize
            # Once data is saved, re-initialize the arrays
            nsize = np.min([n_save, n_iter-i])
            chain_save = np.zeros((ntemps, nwalkers, nsize, ndim))
            logl_save = np.zeros((ntemps, nwalkers, nsize))
            logp_save = np.zeros((ntemps, nwalkers, nsize))
            # Set the saving counter to zero
            isave = 0
        else:
            # increment saving counter
            isave += 1
    
        if i % (n_verbose -1) == 0:
            print("Iteration " + str(i) + " completed.")
        # Increment global counter
        i += 1


t2 = time.time()
print(t2-t1)
# Out:
# Iteration 0 completed.
# Save data at iteration 99...
# Data saved.
# Save data at iteration 199...
# Data saved.
# Iteration 199 completed.
# Save data at iteration 299...
# Data saved.
# Iteration 398 completed.
# Save data at iteration 399...
# Data saved.
# Save data at iteration 499...
# Data saved.
# Iteration 597 completed.
# Save data at iteration 599...
# Data saved.
# Save data at iteration 699...
# Data saved.
# Iteration 796 completed.
# Save data at iteration 799...
# Data saved.
# Save data at iteration 899...
# Data saved.
# Iteration 995 completed.
# Save data at iteration 999...
# Data saved.
# Save data at iteration 1099...
# Data saved.
# Iteration 1194 completed.
# Save data at iteration 1199...
# Data saved.
# Save data at iteration 1299...
# Data saved.
# Iteration 1393 completed.
# Save data at iteration 1399...
# Data saved.
# Save data at iteration 1499...
# Data saved.
# Iteration 1592 completed.
# Save data at iteration 1599...
# Data saved.
# Save data at iteration 1699...
# Data saved.
# Iteration 1791 completed.
# Save data at iteration 1799...
# Data saved.
# Save data at iteration 1899...
# Data saved.
# Iteration 1990 completed.
# Save data at iteration 1999...
# Data saved.
# Save data at iteration 2099...
# Data saved.
# Iteration 2189 completed.
# Save data at iteration 2199...
# Data saved.
# Save data at iteration 2299...
# Data saved.
# Iteration 2388 completed.
# Save data at iteration 2399...
# Data saved.
# Save data at iteration 2499...
# Data saved.
# Iteration 2587 completed.
# Save data at iteration 2599...
# Data saved.
# Save data at iteration 2699...
# Data saved.
# Iteration 2786 completed.
# Save data at iteration 2799...
# Data saved.
# Save data at iteration 2899...
# Data saved.
# Iteration 2985 completed.
# Save data at iteration 2999...
# Data saved.
# Save data at iteration 3099...
# Data saved.
# Iteration 3184 completed.
# Save data at iteration 3199...
# Data saved.
# Save data at iteration 3299...
# Data saved.
# Iteration 3383 completed.
# Save data at iteration 3399...
# Data saved.
# Save data at iteration 3499...
# Data saved.
# Iteration 3582 completed.
# Save data at iteration 3599...
# Data saved.
# Save data at iteration 3699...
# Data saved.
# Iteration 3781 completed.
# Save data at iteration 3799...
# Data saved.
# Save data at iteration 3899...
# Data saved.
# Iteration 3980 completed.
# Save data at iteration 3999...
# Data saved.
# Save data at iteration 4099...
# Data saved.
# Iteration 4179 completed.
# Save data at iteration 4199...
# Data saved.
# Save data at iteration 4299...
# Data saved.
# Iteration 4378 completed.
# Save data at iteration 4399...
# Data saved.
# Save data at iteration 4499...
# Data saved.
# Iteration 4577 completed.
# Save data at iteration 4599...
# Data saved.
# Save data at iteration 4699...
# Data saved.
# Iteration 4776 completed.
# Save data at iteration 4799...
# Data saved.
# Save data at iteration 4899...
# Data saved.
# Iteration 4975 completed.
# Save data at iteration 4999...
# Data saved.
# Save data at iteration 5099...
# Data saved.
# Iteration 5174 completed.
# Save data at iteration 5199...
# Data saved.
# Save data at iteration 5299...
# Data saved.
# Iteration 5373 completed.
# Save data at iteration 5399...
# Data saved.
# Save data at iteration 5499...
# Data saved.
# Iteration 5572 completed.
# Save data at iteration 5599...
# Data saved.
# Save data at iteration 5699...
# Data saved.
# Iteration 5771 completed.
# Save data at iteration 5799...
# Data saved.
# Save data at iteration 5899...
# Data saved.
# Iteration 5970 completed.
# Save data at iteration 5999...
# Data saved.
# Save data at iteration 6099...
# Data saved.
# Iteration 6169 completed.
# Save data at iteration 6199...
# Data saved.
# Save data at iteration 6299...
# Data saved.
# Iteration 6368 completed.
# Save data at iteration 6399...
# Data saved.
# Save data at iteration 6499...
# Data saved.
# Iteration 6567 completed.
# Save data at iteration 6599...
# Data saved.
# Save data at iteration 6699...
# Data saved.
# Iteration 6766 completed.
# Save data at iteration 6799...
# Data saved.
# Save data at iteration 6899...
# Data saved.
# Iteration 6965 completed.
# Save data at iteration 6999...
# Data saved.
# Save data at iteration 7099...
# Data saved.
# Iteration 7164 completed.
# Save data at iteration 7199...
# Data saved.
# Save data at iteration 7299...
# Data saved.
# Iteration 7363 completed.
# Save data at iteration 7399...
# Data saved.
# Save data at iteration 7499...
# Data saved.
# Iteration 7562 completed.
# Save data at iteration 7599...
# Data saved.
# Save data at iteration 7699...
# Data saved.
# Iteration 7761 completed.
# Save data at iteration 7799...
# Data saved.
# Save data at iteration 7899...
# Data saved.
# Iteration 7960 completed.
# Save data at iteration 7999...
# Data saved.
# Save data at iteration 8099...
# Data saved.
# Iteration 8159 completed.
# Save data at iteration 8199...
# Data saved.
# Save data at iteration 8299...
# Data saved.
# Iteration 8358 completed.
# Save data at iteration 8399...
# Data saved.
# Save data at iteration 8499...
# Data saved.
# Iteration 8557 completed.
# Save data at iteration 8599...
# Data saved.
# Save data at iteration 8699...
# Data saved.
# Iteration 8756 completed.
# Save data at iteration 8799...
# Data saved.
# Save data at iteration 8899...
# Data saved.
# Iteration 8955 completed.
# Save data at iteration 8999...
# Data saved.
# Save data at iteration 9099...
# Data saved.
# Iteration 9154 completed.
# Save data at iteration 9199...
# Data saved.
# Save data at iteration 9299...
# Data saved.
# Iteration 9353 completed.
# Save data at iteration 9399...
# Data saved.
# Save data at iteration 9499...
# Data saved.
# Iteration 9552 completed.
# Save data at iteration 9599...
# Data saved.
# Save data at iteration 9699...
# Data saved.
# Iteration 9751 completed.
# Save data at iteration 9799...
# Data saved.
# Save data at iteration 9899...
# Data saved.
# Iteration 9950 completed.
# Save data at iteration 9999...
# Data saved.
# Save data at iteration 10099...
# Data saved.
# Iteration 10149 completed.
# Save data at iteration 10199...
# Data saved.
# Save data at iteration 10299...
# Data saved.
# Iteration 10348 completed.
# Save data at iteration 10399...
# Data saved.
# Save data at iteration 10499...
# Data saved.
# Iteration 10547 completed.
# Save data at iteration 10599...
# Data saved.
# Save data at iteration 10699...
# Data saved.
# Iteration 10746 completed.
# Save data at iteration 10799...
# Data saved.
# Save data at iteration 10899...
# Data saved.
# Iteration 10945 completed.
# Save data at iteration 10999...
# Data saved.
# Save data at iteration 11099...
# Data saved.
# Iteration 11144 completed.
# Save data at iteration 11199...
# Data saved.
# Save data at iteration 11299...
# Data saved.
# Iteration 11343 completed.
# Save data at iteration 11399...
# Data saved.
# Save data at iteration 11499...
# Data saved.
# Iteration 11542 completed.
# Save data at iteration 11599...
# Data saved.
# Save data at iteration 11699...
# Data saved.
# Iteration 11741 completed.
# Save data at iteration 11799...
# Data saved.
# Save data at iteration 11899...
# Data saved.
# Iteration 11940 completed.
# Save data at iteration 11999...
# Data saved.
# Save data at iteration 12099...
# Data saved.
# Iteration 12139 completed.
# Save data at iteration 12199...
# Data saved.
# Save data at iteration 12299...
# Data saved.
# Iteration 12338 completed.
# Save data at iteration 12399...
# Data saved.
# Save data at iteration 12499...
# Data saved.
# Iteration 12537 completed.
# Save data at iteration 12599...
# Data saved.
# Save data at iteration 12699...
# Data saved.
# Iteration 12736 completed.
# Save data at iteration 12799...
# Data saved.
# Save data at iteration 12899...
# Data saved.
# Iteration 12935 completed.
# Save data at iteration 12999...
# Data saved.
# Save data at iteration 13099...
# Data saved.
# Iteration 13134 completed.
# Save data at iteration 13199...
# Data saved.
# Save data at iteration 13299...
# Data saved.
# Iteration 13333 completed.
# Save data at iteration 13399...
# Data saved.
# Save data at iteration 13499...
# Data saved.
# Iteration 13532 completed.
# Save data at iteration 13599...
# Data saved.
# Save data at iteration 13699...
# Data saved.
# Iteration 13731 completed.
# Save data at iteration 13799...
# Data saved.
# Save data at iteration 13899...
# Data saved.
# Iteration 13930 completed.
# Save data at iteration 13999...
# Data saved.
# Save data at iteration 14099...
# Data saved.
# Iteration 14129 completed.
# Save data at iteration 14199...
# Data saved.
# Save data at iteration 14299...
# Data saved.
# Iteration 14328 completed.
# Save data at iteration 14399...
# Data saved.
# Save data at iteration 14499...
# Data saved.
# Iteration 14527 completed.
# Save data at iteration 14599...
# Data saved.
# Save data at iteration 14699...
# Data saved.
# Iteration 14726 completed.
# Save data at iteration 14799...
# Data saved.
# Save data at iteration 14899...
# Data saved.
# Iteration 14925 completed.
# Save data at iteration 14999...
# Data saved.
# Save data at iteration 15099...
# Data saved.
# Iteration 15124 completed.
# Save data at iteration 15199...
# Data saved.
# Save data at iteration 15299...
# Data saved.
# Iteration 15323 completed.
# Save data at iteration 15399...
# Data saved.
# Save data at iteration 15499...
# Data saved.
# Iteration 15522 completed.
# Save data at iteration 15599...
# Data saved.
# Save data at iteration 15699...
# Data saved.
# Iteration 15721 completed.
# Save data at iteration 15799...
# Data saved.
# Save data at iteration 15899...
# Data saved.
# Iteration 15920 completed.
# Save data at iteration 15999...
# Data saved.
# Save data at iteration 16099...
# Data saved.
# Iteration 16119 completed.
# Save data at iteration 16199...
# Data saved.
# Save data at iteration 16299...
# Data saved.
# Iteration 16318 completed.
# Save data at iteration 16399...
# Data saved.
# Save data at iteration 16499...
# Data saved.
# Iteration 16517 completed.
# Save data at iteration 16599...
# Data saved.
# Save data at iteration 16699...
# Data saved.
# Iteration 16716 completed.
# Save data at iteration 16799...
# Data saved.
# Save data at iteration 16899...
# Data saved.
# Iteration 16915 completed.
# Save data at iteration 16999...
# Data saved.
# Save data at iteration 17099...
# Data saved.
# Iteration 17114 completed.
# Save data at iteration 17199...
# Data saved.
# Save data at iteration 17299...
# Data saved.
# Iteration 17313 completed.
# Save data at iteration 17399...
# Data saved.
# Save data at iteration 17499...
# Data saved.
# Iteration 17512 completed.
# Save data at iteration 17599...
# Data saved.
# Save data at iteration 17699...
# Data saved.
# Iteration 17711 completed.
# Save data at iteration 17799...
# Data saved.
# Save data at iteration 17899...
# Data saved.
# Iteration 17910 completed.
# Save data at iteration 17999...
# Data saved.
# Save data at iteration 18099...
# Data saved.
# Iteration 18109 completed.
# Save data at iteration 18199...
# Data saved.
# Save data at iteration 18299...
# Data saved.
# Iteration 18308 completed.
# Save data at iteration 18399...
# Data saved.
# Save data at iteration 18499...
# Data saved.
# Iteration 18507 completed.
# Save data at iteration 18599...
# Data saved.
# Save data at iteration 18699...
# Data saved.
# Iteration 18706 completed.
# Save data at iteration 18799...
# Data saved.
# Save data at iteration 18899...
# Data saved.
# Iteration 18905 completed.
# Save data at iteration 18999...
# Data saved.
# Save data at iteration 19099...
# Data saved.
# Iteration 19104 completed.
# Save data at iteration 19199...
# Data saved.
# Save data at iteration 19299...
# Data saved.
# Iteration 19303 completed.
# Save data at iteration 19399...
# Data saved.
# Save data at iteration 19499...
# Data saved.
# Iteration 19502 completed.
# Save data at iteration 19599...
# Data saved.
# Save data at iteration 19699...
# Data saved.
# Iteration 19701 completed.
# Save data at iteration 19799...
# Data saved.
# Save data at iteration 19899...
# Data saved.
# Iteration 19900 completed.
# Save data at iteration 19999...
# Data saved.
# Save data at iteration 20099...
# Data saved.
# Iteration 20099 completed.
# Save data at iteration 20199...
# Data saved.
# Iteration 20298 completed.
# Save data at iteration 20299...
# Data saved.
# Save data at iteration 20399...
# Data saved.
# Iteration 20497 completed.
# Save data at iteration 20499...
# Data saved.
# Save data at iteration 20599...
# Data saved.
# Iteration 20696 completed.
# Save data at iteration 20699...
# Data saved.
# Save data at iteration 20799...
# Data saved.
# Iteration 20895 completed.
# Save data at iteration 20899...
# Data saved.
# Save data at iteration 20999...
# Data saved.
# Iteration 21094 completed.
# Save data at iteration 21099...
# Data saved.
# Save data at iteration 21199...
# Data saved.
# Iteration 21293 completed.
# Save data at iteration 21299...
# Data saved.
# Save data at iteration 21399...
# Data saved.
# Iteration 21492 completed.
# Save data at iteration 21499...
# Data saved.
# Save data at iteration 21599...
# Data saved.
# Iteration 21691 completed.
# Save data at iteration 21699...
# Data saved.
# Save data at iteration 21799...
# Data saved.
# Iteration 21890 completed.
# Save data at iteration 21899...
# Data saved.
# Save data at iteration 21999...
# Data saved.
# Iteration 22089 completed.
# Save data at iteration 22099...
# Data saved.
# Save data at iteration 22199...
# Data saved.
# Iteration 22288 completed.
# Save data at iteration 22299...
# Data saved.
# Save data at iteration 22399...
# Data saved.
# Iteration 22487 completed.
# Save data at iteration 22499...
# Data saved.
# Save data at iteration 22599...
# Data saved.
# Iteration 22686 completed.
# Save data at iteration 22699...
# Data saved.
# Save data at iteration 22799...
# Data saved.
# Iteration 22885 completed.
# Save data at iteration 22899...
# Data saved.
# Save data at iteration 22999...
# Data saved.
# Iteration 23084 completed.
# Save data at iteration 23099...
# Data saved.
# Save data at iteration 23199...
# Data saved.
# Iteration 23283 completed.
# Save data at iteration 23299...
# Data saved.
# Save data at iteration 23399...
# Data saved.
# Iteration 23482 completed.
# Save data at iteration 23499...
# Data saved.
# Save data at iteration 23599...
# Data saved.
# Iteration 23681 completed.
# Save data at iteration 23699...
# Data saved.
# Save data at iteration 23799...
# Data saved.
# Iteration 23880 completed.
# Save data at iteration 23899...
# Data saved.
# Save data at iteration 23999...
# Data saved.
# Iteration 24079 completed.
# Save data at iteration 24099...
# Data saved.
# Save data at iteration 24199...
# Data saved.
# Iteration 24278 completed.
# Save data at iteration 24299...
# Data saved.
# Save data at iteration 24399...
# Data saved.
# Iteration 24477 completed.
# Save data at iteration 24499...
# Data saved.
# Save data at iteration 24599...
# Data saved.
# Iteration 24676 completed.
# Save data at iteration 24699...
# Data saved.
# Save data at iteration 24799...
# Data saved.
# Iteration 24875 completed.
# Save data at iteration 24899...
# Data saved.
# Save data at iteration 24999...
# Data saved.
# Iteration 25074 completed.
# Save data at iteration 25099...
# Data saved.
# Save data at iteration 25199...
# Data saved.
# Iteration 25273 completed.
# Save data at iteration 25299...
# Data saved.
# Save data at iteration 25399...
# Data saved.
# Iteration 25472 completed.
# Save data at iteration 25499...
# Data saved.
# Save data at iteration 25599...
# Data saved.
# Iteration 25671 completed.
# Save data at iteration 25699...
# Data saved.
# Save data at iteration 25799...
# Data saved.
# Iteration 25870 completed.
# Save data at iteration 25899...
# Data saved.
# Save data at iteration 25999...
# Data saved.
# Iteration 26069 completed.
# Save data at iteration 26099...
# Data saved.
# Save data at iteration 26199...
# Data saved.
# Iteration 26268 completed.
# Save data at iteration 26299...
# Data saved.
# Save data at iteration 26399...
# Data saved.
# Iteration 26467 completed.
# Save data at iteration 26499...
# Data saved.
# Save data at iteration 26599...
# Data saved.
# Iteration 26666 completed.
# Save data at iteration 26699...
# Data saved.
# Save data at iteration 26799...
# Data saved.
# Iteration 26865 completed.
# Save data at iteration 26899...
# Data saved.
# Save data at iteration 26999...
# Data saved.
# Iteration 27064 completed.
# Save data at iteration 27099...
# Data saved.
# Save data at iteration 27199...
# Data saved.
# Iteration 27263 completed.
# Save data at iteration 27299...
# Data saved.
# Save data at iteration 27399...
# Data saved.
# Iteration 27462 completed.
# Save data at iteration 27499...
# Data saved.
# Save data at iteration 27599...
# Data saved.
# Iteration 27661 completed.
# Save data at iteration 27699...
# Data saved.
# Save data at iteration 27799...
# Data saved.
# Iteration 27860 completed.
# Save data at iteration 27899...
# Data saved.
# Save data at iteration 27999...
# Data saved.
# Iteration 28059 completed.
# Save data at iteration 28099...
# Data saved.
# Save data at iteration 28199...
# Data saved.
# Iteration 28258 completed.
# Save data at iteration 28299...
# Data saved.
# Save data at iteration 28399...
# Data saved.
# Iteration 28457 completed.
# Save data at iteration 28499...
# Data saved.
# Save data at iteration 28599...
# Data saved.
# Iteration 28656 completed.
# Save data at iteration 28699...
# Data saved.
# Save data at iteration 28799...
# Data saved.
# Iteration 28855 completed.
# Save data at iteration 28899...
# Data saved.
# Save data at iteration 28999...
# Data saved.
# Iteration 29054 completed.
# Save data at iteration 29099...
# Data saved.
# Save data at iteration 29199...
# Data saved.
# Iteration 29253 completed.
# Save data at iteration 29299...
# Data saved.
# Save data at iteration 29399...
# Data saved.
# Iteration 29452 completed.
# Save data at iteration 29499...
# Data saved.
# Save data at iteration 29599...
# Data saved.
# Iteration 29651 completed.
# Save data at iteration 29699...
# Data saved.
# Save data at iteration 29799...
# Data saved.
# Iteration 29850 completed.
# Save data at iteration 29899...
# Data saved.
# Save data at iteration 29999...
# Data saved.
# Iteration 30049 completed.
# Save data at iteration 30099...
# Data saved.
# Save data at iteration 30199...
# Data saved.
# Iteration 30248 completed.
# Save data at iteration 30299...
# Data saved.
# Save data at iteration 30399...
# Data saved.
# Iteration 30447 completed.
# Save data at iteration 30499...
# Data saved.
# Save data at iteration 30599...
# Data saved.
# Iteration 30646 completed.
# Save data at iteration 30699...
# Data saved.
# Save data at iteration 30799...
# Data saved.
# Iteration 30845 completed.
# Save data at iteration 30899...
# Data saved.
# Save data at iteration 30999...
# Data saved.
# Iteration 31044 completed.
# Save data at iteration 31099...
# Data saved.
# Save data at iteration 31199...
# Data saved.
# Iteration 31243 completed.
# Save data at iteration 31299...
# Data saved.
# Save data at iteration 31399...
# Data saved.
# Iteration 31442 completed.
# Save data at iteration 31499...
# Data saved.
# Save data at iteration 31599...
# Data saved.
# Iteration 31641 completed.
# Save data at iteration 31699...
# Data saved.
# Save data at iteration 31799...
# Data saved.
# Iteration 31840 completed.
# Save data at iteration 31899...
# Data saved.
# Save data at iteration 31999...
# Data saved.
# Iteration 32039 completed.
# Save data at iteration 32099...
# Data saved.
# Save data at iteration 32199...
# Data saved.
# Iteration 32238 completed.
# Save data at iteration 32299...
# Data saved.
# Save data at iteration 32399...
# Data saved.
# Iteration 32437 completed.
# Save data at iteration 32499...
# Data saved.
# Save data at iteration 32599...
# Data saved.
# Iteration 32636 completed.
# Save data at iteration 32699...
# Data saved.
# Save data at iteration 32799...
# Data saved.
# Iteration 32835 completed.
# Save data at iteration 32899...
# Data saved.
# Save data at iteration 32999...
# Data saved.
# Iteration 33034 completed.
# Save data at iteration 33099...
# Data saved.
# Save data at iteration 33199...
# Data saved.
# Iteration 33233 completed.
# Save data at iteration 33299...
# Data saved.
# Save data at iteration 33399...
# Data saved.
# Iteration 33432 completed.
# Save data at iteration 33499...
# Data saved.
# Save data at iteration 33599...
# Data saved.
# Iteration 33631 completed.
# Save data at iteration 33699...
# Data saved.
# Save data at iteration 33799...
# Data saved.
# Iteration 33830 completed.
# Save data at iteration 33899...
# Data saved.
# Save data at iteration 33999...
# Data saved.
# Iteration 34029 completed.
# Save data at iteration 34099...
# Data saved.
# Save data at iteration 34199...
# Data saved.
# Iteration 34228 completed.
# Save data at iteration 34299...
# Data saved.
# Save data at iteration 34399...
# Data saved.
# Iteration 34427 completed.
# Save data at iteration 34499...
# Data saved.
# Save data at iteration 34599...
# Data saved.
# Iteration 34626 completed.
# Save data at iteration 34699...
# Data saved.
# Save data at iteration 34799...
# Data saved.
# Iteration 34825 completed.
# Save data at iteration 34899...
# Data saved.
# Save data at iteration 34999...
# Data saved.
# Iteration 35024 completed.
# Save data at iteration 35099...
# Data saved.
# Save data at iteration 35199...
# Data saved.
# Iteration 35223 completed.
# Save data at iteration 35299...
# Data saved.
# Save data at iteration 35399...
# Data saved.
# Iteration 35422 completed.
# Save data at iteration 35499...
# Data saved.
# Save data at iteration 35599...
# Data saved.
# Iteration 35621 completed.
# Save data at iteration 35699...
# Data saved.
# Save data at iteration 35799...
# Data saved.
# Iteration 35820 completed.
# Save data at iteration 35899...
# Data saved.
# Save data at iteration 35999...
# Data saved.
# Iteration 36019 completed.
# Save data at iteration 36099...
# Data saved.
# Save data at iteration 36199...
# Data saved.
# Iteration 36218 completed.
# Save data at iteration 36299...
# Data saved.
# Save data at iteration 36399...
# Data saved.
# Iteration 36417 completed.
# Save data at iteration 36499...
# Data saved.
# Save data at iteration 36599...
# Data saved.
# Iteration 36616 completed.
# Save data at iteration 36699...
# Data saved.
# Save data at iteration 36799...
# Data saved.
# Iteration 36815 completed.
# Save data at iteration 36899...
# Data saved.
# Save data at iteration 36999...
# Data saved.
# Iteration 37014 completed.
# Save data at iteration 37099...
# Data saved.
# Save data at iteration 37199...
# Data saved.
# Iteration 37213 completed.
# Save data at iteration 37299...
# Data saved.
# Save data at iteration 37399...
# Data saved.
# Iteration 37412 completed.
# Save data at iteration 37499...
# Data saved.
# Save data at iteration 37599...
# Data saved.
# Iteration 37611 completed.
# Save data at iteration 37699...
# Data saved.
# Save data at iteration 37799...
# Data saved.
# Iteration 37810 completed.
# Save data at iteration 37899...
# Data saved.
# Save data at iteration 37999...
# Data saved.
# Iteration 38009 completed.
# Save data at iteration 38099...
# Data saved.
# Save data at iteration 38199...
# Data saved.
# Iteration 38208 completed.
# Save data at iteration 38299...
# Data saved.
# Save data at iteration 38399...
# Data saved.
# Iteration 38407 completed.
# Save data at iteration 38499...
# Data saved.
# Save data at iteration 38599...
# Data saved.
# Iteration 38606 completed.
# Save data at iteration 38699...
# Data saved.
# Save data at iteration 38799...
# Data saved.
# Iteration 38805 completed.
# Save data at iteration 38899...
# Data saved.
# Save data at iteration 38999...
# Data saved.
# Iteration 39004 completed.
# Save data at iteration 39099...
# Data saved.
# Save data at iteration 39199...
# Data saved.
# Iteration 39203 completed.
# Save data at iteration 39299...
# Data saved.
# Save data at iteration 39399...
# Data saved.
# Iteration 39402 completed.
# Save data at iteration 39499...
# Data saved.
# Save data at iteration 39599...
# Data saved.
# Iteration 39601 completed.
# Save data at iteration 39699...
# Data saved.
# Save data at iteration 39799...
# Data saved.
# Iteration 39800 completed.
# Save data at iteration 39899...
# Data saved.
# Save data at iteration 39999...
# Data saved.
# Iteration 39999 completed.
# Save data at iteration 40099...
# Data saved.
# Iteration 40198 completed.
# Save data at iteration 40199...
# Data saved.
# Save data at iteration 40299...
# Data saved.
# Iteration 40397 completed.
# Save data at iteration 40399...
# Data saved.
# Save data at iteration 40499...
# Data saved.
# Iteration 40596 completed.
# Save data at iteration 40599...
# Data saved.
# Save data at iteration 40699...
# Data saved.
# Iteration 40795 completed.
# Save data at iteration 40799...
# Data saved.
# Save data at iteration 40899...
# Data saved.
# Iteration 40994 completed.
# Save data at iteration 40999...
# Data saved.
# Save data at iteration 41099...
# Data saved.
# Iteration 41193 completed.
# Save data at iteration 41199...
# Data saved.
# Save data at iteration 41299...
# Data saved.
# Iteration 41392 completed.
# Save data at iteration 41399...
# Data saved.
# Save data at iteration 41499...
# Data saved.
# Iteration 41591 completed.
# Save data at iteration 41599...
# Data saved.
# Save data at iteration 41699...
# Data saved.
# Iteration 41790 completed.
# Save data at iteration 41799...
# Data saved.
# Save data at iteration 41899...
# Data saved.
# Iteration 41989 completed.
# Save data at iteration 41999...
# Data saved.
# Save data at iteration 42099...
# Data saved.
# Iteration 42188 completed.
# Save data at iteration 42199...
# Data saved.
# Save data at iteration 42299...
# Data saved.
# Iteration 42387 completed.
# Save data at iteration 42399...
# Data saved.
# Save data at iteration 42499...
# Data saved.
# Iteration 42586 completed.
# Save data at iteration 42599...
# Data saved.
# Save data at iteration 42699...
# Data saved.
# Iteration 42785 completed.
# Save data at iteration 42799...
# Data saved.
# Save data at iteration 42899...
# Data saved.
# Iteration 42984 completed.
# Save data at iteration 42999...
# Data saved.
# Save data at iteration 43099...
# Data saved.
# Iteration 43183 completed.
# Save data at iteration 43199...
# Data saved.
# Save data at iteration 43299...
# Data saved.
# Iteration 43382 completed.
# Save data at iteration 43399...
# Data saved.
# Save data at iteration 43499...
# Data saved.
# Iteration 43581 completed.
# Save data at iteration 43599...
# Data saved.
# Save data at iteration 43699...
# Data saved.
# Iteration 43780 completed.
# Save data at iteration 43799...
# Data saved.
# Save data at iteration 43899...
# Data saved.
# Iteration 43979 completed.
# Save data at iteration 43999...
# Data saved.
# Save data at iteration 44099...
# Data saved.
# Iteration 44178 completed.
# Save data at iteration 44199...
# Data saved.
# Save data at iteration 44299...
# Data saved.
# Iteration 44377 completed.
# Save data at iteration 44399...
# Data saved.
# Save data at iteration 44499...
# Data saved.
# Iteration 44576 completed.
# Save data at iteration 44599...
# Data saved.
# Save data at iteration 44699...
# Data saved.
# Iteration 44775 completed.
# Save data at iteration 44799...
# Data saved.
# Save data at iteration 44899...
# Data saved.
# Iteration 44974 completed.
# Save data at iteration 44999...
# Data saved.
# Save data at iteration 45099...
# Data saved.
# Iteration 45173 completed.
# Save data at iteration 45199...
# Data saved.
# Save data at iteration 45299...
# Data saved.
# Iteration 45372 completed.
# Save data at iteration 45399...
# Data saved.
# Save data at iteration 45499...
# Data saved.
# Iteration 45571 completed.
# Save data at iteration 45599...
# Data saved.
# Save data at iteration 45699...
# Data saved.
# Iteration 45770 completed.
# Save data at iteration 45799...
# Data saved.
# Save data at iteration 45899...
# Data saved.
# Iteration 45969 completed.
# Save data at iteration 45999...
# Data saved.
# Save data at iteration 46099...
# Data saved.
# Iteration 46168 completed.
# Save data at iteration 46199...
# Data saved.
# Save data at iteration 46299...
# Data saved.
# Iteration 46367 completed.
# Save data at iteration 46399...
# Data saved.
# Save data at iteration 46499...
# Data saved.
# Iteration 46566 completed.
# Save data at iteration 46599...
# Data saved.
# Save data at iteration 46699...
# Data saved.
# Iteration 46765 completed.
# Save data at iteration 46799...
# Data saved.
# Save data at iteration 46899...
# Data saved.
# Iteration 46964 completed.
# Save data at iteration 46999...
# Data saved.
# Save data at iteration 47099...
# Data saved.
# Iteration 47163 completed.
# Save data at iteration 47199...
# Data saved.
# Save data at iteration 47299...
# Data saved.
# Iteration 47362 completed.
# Save data at iteration 47399...
# Data saved.
# Save data at iteration 47499...
# Data saved.
# Iteration 47561 completed.
# Save data at iteration 47599...
# Data saved.
# Save data at iteration 47699...
# Data saved.
# Iteration 47760 completed.
# Save data at iteration 47799...
# Data saved.
# Save data at iteration 47899...
# Data saved.
# Iteration 47959 completed.
# Save data at iteration 47999...
# Data saved.
# Save data at iteration 48099...
# Data saved.
# Iteration 48158 completed.
# Save data at iteration 48199...
# Data saved.
# Save data at iteration 48299...
# Data saved.
# Iteration 48357 completed.
# Save data at iteration 48399...
# Data saved.
# Save data at iteration 48499...
# Data saved.
# Iteration 48556 completed.
# Save data at iteration 48599...
# Data saved.
# Save data at iteration 48699...
# Data saved.
# Iteration 48755 completed.
# Save data at iteration 48799...
# Data saved.
# Save data at iteration 48899...
# Data saved.
# Iteration 48954 completed.
# Save data at iteration 48999...
# Data saved.
# Save data at iteration 49099...
# Data saved.
# Iteration 49153 completed.
# Save data at iteration 49199...
# Data saved.
# Save data at iteration 49299...
# Data saved.
# Iteration 49352 completed.
# Save data at iteration 49399...
# Data saved.
# Save data at iteration 49499...
# Data saved.
# Iteration 49551 completed.
# Save data at iteration 49599...
# Data saved.
# Save data at iteration 49699...
# Data saved.
# Iteration 49750 completed.
# Save data at iteration 49799...
# Data saved.
# Save data at iteration 49899...
# Data saved.
# Iteration 49949 completed.
# Save data at iteration 49999...
# Data saved.
# Save data at iteration 50099...
# Data saved.
# Iteration 50148 completed.
# Save data at iteration 50199...
# Data saved.
# Save data at iteration 50299...
# Data saved.
# Iteration 50347 completed.
# Save data at iteration 50399...
# Data saved.
# Save data at iteration 50499...
# Data saved.
# Iteration 50546 completed.
# Save data at iteration 50599...
# Data saved.
# Save data at iteration 50699...
# Data saved.
# Iteration 50745 completed.
# Save data at iteration 50799...
# Data saved.
# Save data at iteration 50899...
# Data saved.
# Iteration 50944 completed.
# Save data at iteration 50999...
# Data saved.
# Save data at iteration 51099...
# Data saved.
# Iteration 51143 completed.
# Save data at iteration 51199...
# Data saved.
# Save data at iteration 51299...
# Data saved.
# Iteration 51342 completed.
# Save data at iteration 51399...
# Data saved.
# Save data at iteration 51499...
# Data saved.
# Iteration 51541 completed.
# Save data at iteration 51599...
# Data saved.
# Save data at iteration 51699...
# Data saved.
# Iteration 51740 completed.
# Save data at iteration 51799...
# Data saved.
# Save data at iteration 51899...
# Data saved.
# Iteration 51939 completed.
# Save data at iteration 51999...
# Data saved.
# Save data at iteration 52099...
# Data saved.
# Iteration 52138 completed.
# Save data at iteration 52199...
# Data saved.
# Save data at iteration 52299...
# Data saved.
# Iteration 52337 completed.
# Save data at iteration 52399...
# Data saved.
# Save data at iteration 52499...
# Data saved.
# Iteration 52536 completed.
# Save data at iteration 52599...
# Data saved.
# Save data at iteration 52699...
# Data saved.
# Iteration 52735 completed.
# Save data at iteration 52799...
# Data saved.
# Save data at iteration 52899...
# Data saved.
# Iteration 52934 completed.
# Save data at iteration 52999...
# Data saved.
# Save data at iteration 53099...
# Data saved.
# Iteration 53133 completed.
# Save data at iteration 53199...
# Data saved.
# Save data at iteration 53299...
# Data saved.
# Iteration 53332 completed.
# Save data at iteration 53399...
# Data saved.
# Save data at iteration 53499...
# Data saved.
# Iteration 53531 completed.
# Save data at iteration 53599...
# Data saved.
# Save data at iteration 53699...
# Data saved.
# Iteration 53730 completed.
# Save data at iteration 53799...
# Data saved.
# Save data at iteration 53899...
# Data saved.
# Iteration 53929 completed.
# Save data at iteration 53999...
# Data saved.
# Save data at iteration 54099...
# Data saved.
# Iteration 54128 completed.
# Save data at iteration 54199...
# Data saved.
# Save data at iteration 54299...
# Data saved.
# Iteration 54327 completed.
# Save data at iteration 54399...
# Data saved.
# Save data at iteration 54499...
# Data saved.
# Iteration 54526 completed.
# Save data at iteration 54599...
# Data saved.
# Save data at iteration 54699...
# Data saved.
# Iteration 54725 completed.
# Save data at iteration 54799...
# Data saved.
# Save data at iteration 54899...
# Data saved.
# Iteration 54924 completed.
# Save data at iteration 54999...
# Data saved.
# Save data at iteration 55099...
# Data saved.
# Iteration 55123 completed.
# Save data at iteration 55199...
# Data saved.
# Save data at iteration 55299...
# Data saved.
# Iteration 55322 completed.
# Save data at iteration 55399...
# Data saved.
# Save data at iteration 55499...
# Data saved.
# Iteration 55521 completed.
# Save data at iteration 55599...
# Data saved.
# Save data at iteration 55699...
# Data saved.
# Iteration 55720 completed.
# Save data at iteration 55799...
# Data saved.
# Save data at iteration 55899...
# Data saved.
# Iteration 55919 completed.
# Save data at iteration 55999...
# Data saved.
# Save data at iteration 56099...
# Data saved.
# Iteration 56118 completed.
# Save data at iteration 56199...
# Data saved.
# Save data at iteration 56299...
# Data saved.
# Iteration 56317 completed.
# Save data at iteration 56399...
# Data saved.
# Save data at iteration 56499...
# Data saved.
# Iteration 56516 completed.
# Save data at iteration 56599...
# Data saved.
# Save data at iteration 56699...
# Data saved.
# Iteration 56715 completed.
# Save data at iteration 56799...
# Data saved.
# Save data at iteration 56899...
# Data saved.
# Iteration 56914 completed.
# Save data at iteration 56999...
# Data saved.
# Save data at iteration 57099...
# Data saved.
# Iteration 57113 completed.
# Save data at iteration 57199...
# Data saved.
# Save data at iteration 57299...
# Data saved.
# Iteration 57312 completed.
# Save data at iteration 57399...
# Data saved.
# Save data at iteration 57499...
# Data saved.
# Iteration 57511 completed.
# Save data at iteration 57599...
# Data saved.
# Save data at iteration 57699...
# Data saved.
# Iteration 57710 completed.
# Save data at iteration 57799...
# Data saved.
# Save data at iteration 57899...
# Data saved.
# Iteration 57909 completed.
# Save data at iteration 57999...
# Data saved.
# Save data at iteration 58099...
# Data saved.
# Iteration 58108 completed.
# Save data at iteration 58199...
# Data saved.
# Save data at iteration 58299...
# Data saved.
# Iteration 58307 completed.
# Save data at iteration 58399...
# Data saved.
# Save data at iteration 58499...
# Data saved.
# Iteration 58506 completed.
# Save data at iteration 58599...
# Data saved.
# Save data at iteration 58699...
# Data saved.
# Iteration 58705 completed.
# Save data at iteration 58799...
# Data saved.
# Save data at iteration 58899...
# Data saved.
# Iteration 58904 completed.
# Save data at iteration 58999...
# Data saved.
# Save data at iteration 59099...
# Data saved.
# Iteration 59103 completed.
# Save data at iteration 59199...
# Data saved.
# Save data at iteration 59299...
# Data saved.
# Iteration 59302 completed.
# Save data at iteration 59399...
# Data saved.
# Save data at iteration 59499...
# Data saved.
# Iteration 59501 completed.
# Save data at iteration 59599...
# Data saved.
# Save data at iteration 59699...
# Data saved.
# Iteration 59700 completed.
# Save data at iteration 59799...
# Data saved.
# Save data at iteration 59899...
# Data saved.
# Iteration 59899 completed.
# Save data at iteration 59999...
# Data saved.
# Iteration 60098 completed.
# Save data at iteration 60099...
# Data saved.
# Save data at iteration 60199...
# Data saved.
# Iteration 60297 completed.
# Save data at iteration 60299...
# Data saved.
# Save data at iteration 60399...
# Data saved.
# Iteration 60496 completed.
# Save data at iteration 60499...
# Data saved.
# Save data at iteration 60599...
# Data saved.
# Iteration 60695 completed.
# Save data at iteration 60699...
# Data saved.
# Save data at iteration 60799...
# Data saved.
# Iteration 60894 completed.
# Save data at iteration 60899...
# Data saved.
# Save data at iteration 60999...
# Data saved.
# Iteration 61093 completed.
# Save data at iteration 61099...
# Data saved.
# Save data at iteration 61199...
# Data saved.
# Iteration 61292 completed.
# Save data at iteration 61299...
# Data saved.
# Save data at iteration 61399...
# Data saved.
# Iteration 61491 completed.
# Save data at iteration 61499...
# Data saved.
# Save data at iteration 61599...
# Data saved.
# Iteration 61690 completed.
# Save data at iteration 61699...
# Data saved.
# Save data at iteration 61799...
# Data saved.
# Iteration 61889 completed.
# Save data at iteration 61899...
# Data saved.
# Save data at iteration 61999...
# Data saved.
# Iteration 62088 completed.
# Save data at iteration 62099...
# Data saved.
# Save data at iteration 62199...
# Data saved.
# Iteration 62287 completed.
# Save data at iteration 62299...
# Data saved.
# Save data at iteration 62399...
# Data saved.
# Iteration 62486 completed.
# Save data at iteration 62499...
# Data saved.
# Save data at iteration 62599...
# Data saved.
# Iteration 62685 completed.
# Save data at iteration 62699...
# Data saved.
# Save data at iteration 62799...
# Data saved.
# Iteration 62884 completed.
# Save data at iteration 62899...
# Data saved.
# Save data at iteration 62999...
# Data saved.
# Iteration 63083 completed.
# Save data at iteration 63099...
# Data saved.
# Save data at iteration 63199...
# Data saved.
# Iteration 63282 completed.
# Save data at iteration 63299...
# Data saved.
# Save data at iteration 63399...
# Data saved.
# Iteration 63481 completed.
# Save data at iteration 63499...
# Data saved.
# Save data at iteration 63599...
# Data saved.
# Iteration 63680 completed.
# Save data at iteration 63699...
# Data saved.
# Save data at iteration 63799...
# Data saved.
# Iteration 63879 completed.
# Save data at iteration 63899...
# Data saved.
# Save data at iteration 63999...
# Data saved.
# Iteration 64078 completed.
# Save data at iteration 64099...
# Data saved.
# Save data at iteration 64199...
# Data saved.
# Iteration 64277 completed.
# Save data at iteration 64299...
# Data saved.
# Save data at iteration 64399...
# Data saved.
# Iteration 64476 completed.
# Save data at iteration 64499...
# Data saved.
# Save data at iteration 64599...
# Data saved.
# Iteration 64675 completed.
# Save data at iteration 64699...
# Data saved.
# Save data at iteration 64799...
# Data saved.
# Iteration 64874 completed.
# Save data at iteration 64899...
# Data saved.
# Save data at iteration 64999...
# Data saved.
# Iteration 65073 completed.
# Save data at iteration 65099...
# Data saved.
# Save data at iteration 65199...
# Data saved.
# Iteration 65272 completed.
# Save data at iteration 65299...
# Data saved.
# Save data at iteration 65399...
# Data saved.
# Iteration 65471 completed.
# Save data at iteration 65499...
# Data saved.
# Save data at iteration 65599...
# Data saved.
# Iteration 65670 completed.
# Save data at iteration 65699...
# Data saved.
# Save data at iteration 65799...
# Data saved.
# Iteration 65869 completed.
# Save data at iteration 65899...
# Data saved.
# Save data at iteration 65999...
# Data saved.
# Iteration 66068 completed.
# Save data at iteration 66099...
# Data saved.
# Save data at iteration 66199...
# Data saved.
# Iteration 66267 completed.
# Save data at iteration 66299...
# Data saved.
# Save data at iteration 66399...
# Data saved.
# Iteration 66466 completed.
# Save data at iteration 66499...
# Data saved.
# Save data at iteration 66599...
# Data saved.
# Iteration 66665 completed.
# Save data at iteration 66699...
# Data saved.
# Save data at iteration 66799...
# Data saved.
# Iteration 66864 completed.
# Save data at iteration 66899...
# Data saved.
# Save data at iteration 66999...
# Data saved.
# Iteration 67063 completed.
# Save data at iteration 67099...
# Data saved.
# Save data at iteration 67199...
# Data saved.
# Iteration 67262 completed.
# Save data at iteration 67299...
# Data saved.
# Save data at iteration 67399...
# Data saved.
# Iteration 67461 completed.
# Save data at iteration 67499...
# Data saved.
# Save data at iteration 67599...
# Data saved.
# Iteration 67660 completed.
# Save data at iteration 67699...
# Data saved.
# Save data at iteration 67799...
# Data saved.
# Iteration 67859 completed.
# Save data at iteration 67899...
# Data saved.
# Save data at iteration 67999...
# Data saved.
# Iteration 68058 completed.
# Save data at iteration 68099...
# Data saved.
# Save data at iteration 68199...
# Data saved.
# Iteration 68257 completed.
# Save data at iteration 68299...
# Data saved.
# Save data at iteration 68399...
# Data saved.
# Iteration 68456 completed.
# Save data at iteration 68499...
# Data saved.
# Save data at iteration 68599...
# Data saved.
# Iteration 68655 completed.
# Save data at iteration 68699...
# Data saved.
# Save data at iteration 68799...
# Data saved.
# Iteration 68854 completed.
# Save data at iteration 68899...
# Data saved.
# Save data at iteration 68999...
# Data saved.
# Iteration 69053 completed.
# Save data at iteration 69099...
# Data saved.
# Save data at iteration 69199...
# Data saved.
# Iteration 69252 completed.
# Save data at iteration 69299...
# Data saved.
# Save data at iteration 69399...
# Data saved.
# Iteration 69451 completed.
# Save data at iteration 69499...
# Data saved.
# Save data at iteration 69599...
# Data saved.
# Iteration 69650 completed.
# Save data at iteration 69699...
# Data saved.
# Save data at iteration 69799...
# Data saved.
# Iteration 69849 completed.
# Save data at iteration 69899...
# Data saved.
# Save data at iteration 69999...
# Data saved.
# Iteration 70048 completed.
# Save data at iteration 70099...
# Data saved.
# Save data at iteration 70199...
# Data saved.
# Iteration 70247 completed.
# Save data at iteration 70299...
# Data saved.
# Save data at iteration 70399...
# Data saved.
# Iteration 70446 completed.
# Save data at iteration 70499...
# Data saved.
# Save data at iteration 70599...
# Data saved.
# Iteration 70645 completed.
# Save data at iteration 70699...
# Data saved.
# Save data at iteration 70799...
# Data saved.
# Iteration 70844 completed.
# Save data at iteration 70899...
# Data saved.
# Save data at iteration 70999...
# Data saved.
# Iteration 71043 completed.
# Save data at iteration 71099...
# Data saved.
# Save data at iteration 71199...
# Data saved.
# Iteration 71242 completed.
# Save data at iteration 71299...
# Data saved.
# Save data at iteration 71399...
# Data saved.
# Iteration 71441 completed.
# Save data at iteration 71499...
# Data saved.
# Save data at iteration 71599...
# Data saved.
# Iteration 71640 completed.
# Save data at iteration 71699...
# Data saved.
# Save data at iteration 71799...
# Data saved.
# Iteration 71839 completed.
# Save data at iteration 71899...
# Data saved.
# Save data at iteration 71999...
# Data saved.
# Iteration 72038 completed.
# Save data at iteration 72099...
# Data saved.
# Save data at iteration 72199...
# Data saved.
# Iteration 72237 completed.
# Save data at iteration 72299...
# Data saved.
# Save data at iteration 72399...
# Data saved.
# Iteration 72436 completed.
# Save data at iteration 72499...
# Data saved.
# Save data at iteration 72599...
# Data saved.
# Iteration 72635 completed.
# Save data at iteration 72699...
# Data saved.
# Save data at iteration 72799...
# Data saved.
# Iteration 72834 completed.
# Save data at iteration 72899...
# Data saved.
# Save data at iteration 72999...
# Data saved.
# Iteration 73033 completed.
# Save data at iteration 73099...
# Data saved.
# Save data at iteration 73199...
# Data saved.
# Iteration 73232 completed.
# Save data at iteration 73299...
# Data saved.
# Save data at iteration 73399...
# Data saved.
# Iteration 73431 completed.
# Save data at iteration 73499...
# Data saved.
# Save data at iteration 73599...
# Data saved.
# Iteration 73630 completed.
# Save data at iteration 73699...
# Data saved.
# Save data at iteration 73799...
# Data saved.
# Iteration 73829 completed.
# Save data at iteration 73899...
# Data saved.
# Save data at iteration 73999...
# Data saved.
# Iteration 74028 completed.
# Save data at iteration 74099...
# Data saved.
# Save data at iteration 74199...
# Data saved.
# Iteration 74227 completed.
# Save data at iteration 74299...
# Data saved.
# Save data at iteration 74399...
# Data saved.
# Iteration 74426 completed.
# Save data at iteration 74499...
# Data saved.
# Save data at iteration 74599...
# Data saved.
# Iteration 74625 completed.
# Save data at iteration 74699...
# Data saved.
# Save data at iteration 74799...
# Data saved.
# Iteration 74824 completed.
# Save data at iteration 74899...
# Data saved.
# Save data at iteration 74999...
# Data saved.
# Iteration 75023 completed.
# Save data at iteration 75099...
# Data saved.
# Save data at iteration 75199...
# Data saved.
# Iteration 75222 completed.
# Save data at iteration 75299...
# Data saved.
# Save data at iteration 75399...
# Data saved.
# Iteration 75421 completed.
# Save data at iteration 75499...
# Data saved.
# Save data at iteration 75599...
# Data saved.
# Iteration 75620 completed.
# Save data at iteration 75699...
# Data saved.
# Save data at iteration 75799...
# Data saved.
# Iteration 75819 completed.
# Save data at iteration 75899...
# Data saved.
# Save data at iteration 75999...
# Data saved.
# Iteration 76018 completed.
# Save data at iteration 76099...
# Data saved.
# Save data at iteration 76199...
# Data saved.
# Iteration 76217 completed.
# Save data at iteration 76299...
# Data saved.
# Save data at iteration 76399...
# Data saved.
# Iteration 76416 completed.
# Save data at iteration 76499...
# Data saved.
# Save data at iteration 76599...
# Data saved.
# Iteration 76615 completed.
# Save data at iteration 76699...
# Data saved.
# Save data at iteration 76799...
# Data saved.
# Iteration 76814 completed.
# Save data at iteration 76899...
# Data saved.
# Save data at iteration 76999...
# Data saved.
# Iteration 77013 completed.
# Save data at iteration 77099...
# Data saved.
# Save data at iteration 77199...
# Data saved.
# Iteration 77212 completed.
# Save data at iteration 77299...
# Data saved.
# Save data at iteration 77399...
# Data saved.
# Iteration 77411 completed.
# Save data at iteration 77499...
# Data saved.
# Save data at iteration 77599...
# Data saved.
# Iteration 77610 completed.
# Save data at iteration 77699...
# Data saved.
# Save data at iteration 77799...
# Data saved.
# Iteration 77809 completed.
# Save data at iteration 77899...
# Data saved.
# Save data at iteration 77999...
# Data saved.
# Iteration 78008 completed.
# Save data at iteration 78099...
# Data saved.
# Save data at iteration 78199...
# Data saved.
# Iteration 78207 completed.
# Save data at iteration 78299...
# Data saved.
# Save data at iteration 78399...
# Data saved.
# Iteration 78406 completed.
# Save data at iteration 78499...
# Data saved.
# Save data at iteration 78599...
# Data saved.
# Iteration 78605 completed.
# Save data at iteration 78699...
# Data saved.
# Save data at iteration 78799...
# Data saved.
# Iteration 78804 completed.
# Save data at iteration 78899...
# Data saved.
# Save data at iteration 78999...
# Data saved.
# Iteration 79003 completed.
# Save data at iteration 79099...
# Data saved.
# Save data at iteration 79199...
# Data saved.
# Iteration 79202 completed.
# Save data at iteration 79299...
# Data saved.
# Save data at iteration 79399...
# Data saved.
# Iteration 79401 completed.
# Save data at iteration 79499...
# Data saved.
# Save data at iteration 79599...
# Data saved.
# Iteration 79600 completed.
# Save data at iteration 79699...
# Data saved.
# Save data at iteration 79799...
# Data saved.
# Iteration 79799 completed.
# Save data at iteration 79899...
# Data saved.
# Iteration 79998 completed.
# Save data at iteration 79999...
# Data saved.
# 310424.28530216217

# %%
#logEvidence calculation
log_model, uncertainty = sampler.log_evidence_estimate(fburnin=0.99375)
print("Estimated log evidence for UCB model (500) = ", log_model, "+/-", uncertainty)
log_model_1, uncertainty = sampler.log_evidence_estimate(fburnin=0.95)
print("Estimated log evidence for UCB model (1000) = ", log_model_1, "+/-", uncertainty)
log_model_full, uncertainty = sampler.log_evidence_estimate(fburnin=0.1)
print("Estimated log evidence for UCB model (full) = ", log_model_full, "+/-", uncertainty)
# Out:
# Estimated log evidence for UCB model (500) =  3765.4965259770393 +/- 9.75291503199196
# Estimated log evidence for UCB model (1000) =  3765.04691357902 +/- 9.818056047922255
# Estimated log evidence for UCB model (full) =  3764.9656986509717 +/- 9.840293319485227

# %%
#Running to load separately a registered file
p_sample_true=np.array([-21.84367129,   7.74,       -20.62049506,   0.25881905 ,   1.48352986,
   0.70144304,   4.91653383,   0.41646956])
ndim = len(p_sample_true)
nwalkers = 8 * ndim
ntemps = 20

# Intialize the parameter state
pos = np.random.uniform(low=a,high=b,size=(ntemps, nwalkers, ndim))


hdf5 = HDF5Store('./' + "mychains3008ucbLongNewtest.h5", 
                 "chains", 
                 np.shape(pos), 
                 dtype=float, 
                 compression="gzip", 
                 chunk_len=1)
chains = hdf5.save_to_chain(hdf5.load())

# %%
plt.figure(0)
plt.plot(chains[0, 0, :, 0])
#plt.show()
plt.ylabel(r'$log(h_0)$')
plt.xlabel('Iterations')
#plt.savefig('./bh_fig/11')
# Out:
# Text(0.5, 0, 'Iterations')

# %%
plt.plot(chains[0, 0, :, 1])
#plt.show()
plt.ylabel(r'$f_0$')
plt.xlabel('Iterations')
#plt.savefig('./bh_fig/12')
# Out:
# Text(0.5, 0, 'Iterations')

# %%
plt.plot(chains[0, 0, :, 2])
#plt.show()
plt.ylabel(r'$log(f_0)$')
plt.xlabel('Iterations')
#plt.savefig('./bh_fig/13')
# Out:
# Text(0.5, 0, 'Iterations')

# %%
plt.plot(chains[0, 0, :, 3])
plt.ylabel(r'$sin(\beta)$')
plt.xlabel('Iterations')
#plt.savefig('./bh_fig/14')
# Out:
# Text(0.5, 0, 'Iterations')

# %%
plt.plot(chains[0, 0, :, 4])
plt.ylabel(r'$\lambda$')
plt.xlabel('Iterations')
#plt.savefig('./bh_fig/15')
# Out:
# Text(0.5, 0, 'Iterations')

# %%
burnin =79500
samples_plot = chains[0, :, burnin:, :].reshape((nwalkers*(chains.shape[2]-burnin),chains.shape[-1]))

# %%
plt.rcParams['text.usetex']=True
import corner
figure = corner.corner(samples_plot, labels=["$log_{10}(A)$", "$f_0$ (mHz)", "$\log_{10}(\dot{f}_0)(\log_{10}(\mathrm{Hz.s^{-1}}))$",r"$sin(\beta$)",r"($\lambda$)",r"cos(i)",
                                        r"$\psi$",r"$(\varphi_0)$"],
                      truths=[p_sample_true[0], p_sample_true[1], p_sample_true[2],p_sample_true[3],p_sample_true[4],p_sample_true[5],p_sample_true[6],p_sample_true[7]],
                        # quantiles=[0.16, 0.5, 0.84],
                        show_titles=True,
                        title_kwargs={"fontsize": 12})

plt.savefig('cornerplotucb0309.png')

# %%
#BH priors
from scipy.special import gamma

c = 299792458.0
Phi_s=10**(-3)
logMass_s=8.4
M_star=10**logMass_s
a_c=-1.19
beta2=0.5116394637708428
alpha_moy=0.12
alpha=alpha_moy
chi=0.5

def Dist_BH(M,d):
    return ((1/(d+1))**(beta2)*Phi_s*(M/M_star)**(1+a_c)*np.exp(1-(M/M_star)))

def P_M(M):
    return (Phi_s*(M/(M_star))**(1+a_c)*np.exp(1-(M/M_star)))

#Amplitudeh_0
m=1
def chi_f(alpha_f):
    return (4*alpha_f*m)/(4*alpha_f*m+m)
    
def dist_z(z):
    #return Phi_s*(M_star/z)**(2-beta2)*np.exp(1)*gamma(a-beta2+3)
    return (1/(1+z)**beta2)


C1=float((8e-28/10)*(alpha/0.1)**7*(10**6)*((chi-0.45)/0.1))
C1_Mpc=float((8e-28/10)*(alpha/0.1)**7*((chi-0.45)/0.1))
H=float((2*c/70)*1e-3)

def P_d(x):
    return ((H*d1)**(beta2-1)/(x-d0+H*d1)**(beta2))

def logP_h0local(x):
    x=float(10**x)
    return -np.log(C1_Mpc)+np.log(Phi_s)+(1+a_c)*(np.log(x)-np.log(C1_Mpc*M_star))+(1-(x/C1_Mpc)/M_star)

def logP_h0Brito(x):
    x=10**x
    return np.log((1/C1_Mpc)*(0.005*((x/C1_Mpc)/3*10**6)**(0.3)))

#frequency
C2=(645*10*alpha_moy)/0.1
def logP_f0(x):
    x=float(x*1e-3)
    return 1+np.log(C2*Phi_s)+(1+a_c)*(np.log(C2/M_star)-np.log(x))-(2*np.log(x)+(C2/(x*M_star)))


#frequency derivative

C3=3e-14*10**2*(alpha/0.1)**19*chi**2
def logP_f0dot(x):
    x=float(10**x) 
    return 1+np.log(Phi_s/2)+(1+a_c/2)*np.log(C3)-(1+a_c)*np.log(M_star)-(2+a_c/2)*np.log(x)-np.sqrt(C3/x)/M_star

# %%
def logprior_set3(theta,a,b):
    logh0,f,logfdot,sinbeta,lamb,cos_i,pol,ph=theta
    if (np.all(a <=theta) and np.all(b >= theta)):
        
        p=logP_h0local(logh0)+logP_f0(f)+logP_f0dot(logfdot)
    
    else :
        p=-np.inf
   
    return p

# %%
from multiprocessing import Pool
import os
import time
#Needs to disable numpy internal multithreading 
# # as it does not get along well with multiprocessing
os.environ["OMP_NUM_THREADS"] = "1"
# # pool = None
ndim = len(p_sample_true)
nwalkers = 8 * ndim
ntemps = 20

# Intialize the parameter state
pos = np.random.uniform(low=a,high=b,size=(ntemps, nwalkers, ndim))

# Number of iterations
n_iter = 5000
n_thin = 1
# Save results every 100 samples
n_save = 100
# Print progress every 200 samples
n_verbose = 200
# Initialize iteration counter
i = 0
isave = 0

output_dir = "./"
chain_suffix = "mychains0309smbh.h5"
# logl_suffix = "mylogl.h5"
# logp_suffix = "mylogp.h5"

hdf5 = HDF5Store(output_dir + chain_suffix, 
                 "chains", 
                 np.shape(pos), 
                 dtype=float, 
                 compression="gzip", 
                 chunk_len=1)

# Block of chain to be saved
nsize = np.min([n_save, n_iter])
chain_save = np.zeros((ntemps, nwalkers, nsize, ndim))
logl_save = np.zeros((ntemps, nwalkers, nsize))
logp_save = np.zeros((ntemps, nwalkers, nsize))
t1 = time.time()


with Pool(8) as pool:
    sampler = ptemcee.Sampler(nwalkers, ndim, loglike, logprior_set3, 
                              logpargs=[a,b],loglargs=[], 
                              ntemps=int(ntemps),
                              pool=pool)
    for pstate, lnlike0, lnprob0 in sampler.sample(pos, n_iter, thin=n_thin, storechain=True):
    
        # Store data
        chain_save[:, :, isave, :] = pstate
        logl_save[:, :, isave] = lnlike0
        logp_save[:, :, isave] = lnprob0

        if isave == n_save - 1:
            # If the number of iterations in a multiple of n_save
            print("Save data at iteration " + str(i) + "...")
            # The number of saved iterations at iteration i is
            # saved_it = i // thin
            # ------Samples---------

            hdf5.append(hdf5.chain_to_save(chain_save))
            # ------Log likelihood---------
            # ------Log prior---------
            print("Data saved.")
            # Update the number of samples saved
            isave += nsize
            # Once data is saved, re-initialize the arrays
            nsize = np.min([n_save, n_iter-i])
            chain_save = np.zeros((ntemps, nwalkers, nsize, ndim))
            logl_save = np.zeros((ntemps, nwalkers, nsize))
            logp_save = np.zeros((ntemps, nwalkers, nsize))
            # Set the saving counter to zero
            isave = 0
        else:
            # increment saving counter
            isave += 1
    
        if i % (n_verbose -1) == 0:
            print("Iteration " + str(i) + " completed.")
        # Increment global counter
        i += 1


t2 = time.time()
# Out:
# Iteration 0 completed.
# Save data at iteration 99...
# Data saved.
# Save data at iteration 199...
# Data saved.
# Iteration 199 completed.
# Save data at iteration 299...
# Data saved.
# Iteration 398 completed.
# Save data at iteration 399...
# Data saved.
# Save data at iteration 499...
# Data saved.
# Iteration 597 completed.
# Save data at iteration 599...
# Data saved.
# Save data at iteration 699...
# Data saved.
# Iteration 796 completed.
# Save data at iteration 799...
# Data saved.
# Save data at iteration 899...
# Data saved.
# Iteration 995 completed.
# Save data at iteration 999...
# Data saved.
# Save data at iteration 1099...
# Data saved.
# Iteration 1194 completed.
# Save data at iteration 1199...
# Data saved.
# Save data at iteration 1299...
# Data saved.
# Iteration 1393 completed.
# Save data at iteration 1399...
# Data saved.
# Save data at iteration 1499...
# Data saved.
# Iteration 1592 completed.
# Save data at iteration 1599...
# Data saved.
# Save data at iteration 1699...
# Data saved.
# Iteration 1791 completed.
# Save data at iteration 1799...
# Data saved.
# Save data at iteration 1899...
# Data saved.
# Iteration 1990 completed.
# Save data at iteration 1999...
# Data saved.
# Save data at iteration 2099...
# Data saved.
# Iteration 2189 completed.
# Save data at iteration 2199...
# Data saved.
# Save data at iteration 2299...
# Data saved.
# Iteration 2388 completed.
# Save data at iteration 2399...
# Data saved.
# Save data at iteration 2499...
# Data saved.
# Iteration 2587 completed.
# Save data at iteration 2599...
# Data saved.
# Save data at iteration 2699...
# Data saved.
# Iteration 2786 completed.
# Save data at iteration 2799...
# Data saved.
# Save data at iteration 2899...
# Data saved.
# Iteration 2985 completed.
# Save data at iteration 2999...
# Data saved.
# Save data at iteration 3099...
# Data saved.
# Iteration 3184 completed.
# Save data at iteration 3199...
# Data saved.
# Save data at iteration 3299...
# Data saved.
# Iteration 3383 completed.
# Save data at iteration 3399...
# Data saved.
# Save data at iteration 3499...
# Data saved.
# Iteration 3582 completed.
# Save data at iteration 3599...
# Data saved.
# Save data at iteration 3699...
# Data saved.
# Iteration 3781 completed.
# Save data at iteration 3799...
# Data saved.
# Save data at iteration 3899...
# Data saved.
# Iteration 3980 completed.
# Save data at iteration 3999...
# Data saved.
# Save data at iteration 4099...
# Data saved.
# Iteration 4179 completed.
# Save data at iteration 4199...
# Data saved.
# Save data at iteration 4299...
# Data saved.
# Iteration 4378 completed.
# Save data at iteration 4399...
# Data saved.
# Save data at iteration 4499...
# Data saved.
# Iteration 4577 completed.
# Save data at iteration 4599...
# Data saved.
# Save data at iteration 4699...
# Data saved.
# Iteration 4776 completed.
# Save data at iteration 4799...
# Data saved.
# Save data at iteration 4899...
# Data saved.
# Iteration 4975 completed.
# Save data at iteration 4999...
# Data saved.

# %%
chains_bh = hdf5.save_to_chain(hdf5.load())

# %%
burnin =4500
samples_plot_bh = chains_bh[0, :, burnin:, :].reshape((nwalkers*(chains_bh.shape[2]-burnin),chains_bh.shape[-1]))

# %%
plt.rcParams['text.usetex']=True
figure = corner.corner(samples_plot_bh, labels=["$\log_{10}(A)$", "$f_0$ (mHz)", "$\log_{10}(\dot{f}_0)(\log_{10}(\mathrm{Hz.s^{-1}}))$",r"$sin(\beta$)",r"($\lambda$)",r"cos(i)",
                                        r"$\psi$",r"$(\varphi_0)$"],
                      truths=[p_sample_true[0], p_sample_true[1], p_sample_true[2],p_sample_true[3],p_sample_true[4],p_sample_true[5],p_sample_true[6],p_sample_true[7]],
                        # quantiles=[0.16, 0.5, 0.84],
                        show_titles=True,
                        title_kwargs={"fontsize": 12})

plt.savefig('cornerplot0309bh500.png')
# Out:
# WARNING:root:Too few points to create valid contours

# %%
#logEvidence calculation
log_model, uncertainty = sampler.log_evidence_estimate(fburnin=0.9)
print("Estimated log evidence for SMBH model (500) = ", log_model, "+/-", uncertainty)
#log_model_1, uncertainty = sampler.log_evidence_estimate(fburnin=0.95)
#print("Estimated log evidence for SMBH model (1000) = ", log_model_1, "+/-", uncertainty)
log_model_full, uncertainty = sampler.log_evidence_estimate(fburnin=0.1)
print("Estimated log evidence for SMBH model (full) = ", log_model_full, "+/-", uncertainty)
# Out:
# Estimated log evidence for SMBH model (500) =  3626.2690209776156 +/- 13.005256486358121
# Estimated log evidence for SMBH model (full) =  3508.9101459199974 +/- 52.886797592047515

# %%
#Bayes Factor
logBayesFactor=139.23+-16.25
